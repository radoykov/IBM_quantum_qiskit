# %%
import qiskit

# %% [markdown]
# qiskit.__version__

# %%
qiskit.__version__
# Out:
# '2.4.1'

# %%
from qiskit_ibm_runtime import QiskitRuntimeService
service = QiskitRuntimeService(channel="ibm_quantum_platform", token="YOUR_API_TOKEN")
# Out:
# qiskit_runtime_service._discover_account:WARNING:2026-06-06 14:06:34,717: Loading account with the given token. A saved account will not be used.
# qiskit_runtime_service.__init__:WARNING:2026-06-06 14:06:37,679: Instance was not set at service instantiation. Free and trial plan instances will be prioritized. Based on the following filters: (tags: None, region: us-east, eu-de), and available plans: (open), the available account instances are: open-instance. If you need a specific instance set it explicitly either by using a saved account with a saved default instance or passing it in directly to QiskitRuntimeService().

# %%
backend = service.backend(name = "ibm_kingston")
# Out:
# qiskit_runtime_service.backends:WARNING:2026-06-06 14:15:38,607: Using instance: open-instance, plan: open

# %%
# Initialize your account
from qiskit_ibm_runtime import QiskitRuntimeService

service = QiskitRuntimeService()

service.backends()
# Out:
# qiskit_runtime_service.__init__:WARNING:2026-06-06 14:15:05,098: Instance was not set at service instantiation. Free and trial plan instances will be prioritized. Based on the following filters: (tags: None, region: us-east, eu-de), and available plans: (open), the available account instances are: open-instance. If you need a specific instance set it explicitly either by using a saved account with a saved default instance or passing it in directly to QiskitRuntimeService().
# qiskit_runtime_service.backends:WARNING:2026-06-06 14:15:05,099: Loading instance: open-instance, plan: open
# [<IBMBackend('ibm_marrakesh')>,
#  <IBMBackend('ibm_kingston')>,
#  <IBMBackend('ibm_fez')>]

# %%
backend.num_qubits
# Out:
# 156
